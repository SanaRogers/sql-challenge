# %%
import pandas as pd
from config import username, password
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
from sqlalchemy import create_engine

engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/EmployeeSQL')
connection = engine.connect()

# %%
# import titles table, import salaries table and join by emp_no and group by
# title and mean salaries
employees = pd.read_sql('select * from employees', connection)
employees
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001  1953-07-25     Hideyuki   Zallocco   M
# 1       475053        e0002  1954-11-18        Byong  Delgrande   F
# 2        57444        e0002  1958-01-30        Berry       Babb   F
# 3       421786        s0001  1957-09-28        Xiong   Verhoeff   M
# 4       282238        e0003  1952-10-28   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001  1958-08-14  Constantino    Eastman   M
# 300020  255832        e0002  1955-05-08       Yuping     Dayang   F
# 300021   76671        s0001  1959-06-09       Ortrud   Plessier   M
# 300022  264920        s0001  1959-09-22        Percy   Samarati   F
# 300023  464503        s0002  1964-05-31       Arvind  Slobodova   M
#
#          hire_date
# 0       1990-04-28
# 1       1991-09-07
# 2       1992-03-21
# 3       1987-11-26
# 4       1991-01-18
# ...            ...
# ...

# %%
# import salary info by employee
salaries = pd.read_sql('select * from salaries', connection)
salaries
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
# merge employee and salary info 
merged_df = pd.merge(salaries,employees, on = ["emp_no"])
merged_df
# Out:
#         emp_no  salary emp_title_id  birth_date first_name last_name sex  \
# 0        10001   60117        e0003  1953-09-02     Georgi   Facello   M
# 1        10002   65828        s0001  1964-06-02    Bezalel    Simmel   F
# 2        10003   40006        e0003  1959-12-03      Parto   Bamford   M
# 3        10004   40054        e0003  1954-05-01  Chirstian   Koblick   M
# 4        10005   78228        s0001  1955-01-21    Kyoichi  Maliniak   M
# ...        ...     ...          ...         ...        ...       ...  ..
# 300019  499995   40000        e0002  1958-09-24     Dekang  Lichtner   F
# 300020  499996   58058        e0003  1953-03-07       Zito      Baaz   M
# 300021  499997   49597        e0003  1961-08-03    Berhard    Lenart   M
# 300022  499998   40000        s0001  1956-09-05   Patricia   Breugel   M
# 300023  499999   63707        e0002  1958-05-01     Sachin   Tsukuda   M
#
#          hire_date
# 0       1986-06-26
# 1       1985-11-21
# 2       1986-08-28
# ...

# %%
# import deptartment information and merge to get department names linked to emp_no

departments = pd.read_sql('select * from departments', connection)
dept_emp = pd.read_sql('select * from dept_emp', connection)
dept_merge = pd.merge(demp_emp,departments, on = ["dept_no"])
dept_merge
# Out:
#         emp_no dept_no    dept_name
# 0        10001    d005  Development
# 1        10006    d005  Development
# 2        10008    d005  Development
# 3        10012    d005  Development
# 4        10014    d005  Development
# ...        ...     ...          ...
# 331598  499950    d002      Finance
# 331599  499975    d002      Finance
# 331600  499977    d002      Finance
# 331601  499989    d002      Finance
# 331602  499998    d002      Finance
#
# [331603 rows x 3 columns]

# %%
# final merge to connect departments, employee info and salaries
final_merge = pd.merge(dept_merge,merged_df, on = ["emp_no"])
final_merge
# Out:
#         emp_no dept_no    dept_name  salary emp_title_id  birth_date  \
# 0        10001    d005  Development   60117        e0003  1953-09-02
# 1        10006    d005  Development   40000        e0003  1953-04-20
# 2        10008    d005  Development   46671        e0001  1958-02-19
# 3        10012    d005  Development   40000        e0003  1960-10-04
# 4        10014    d005  Development   46168        e0002  1956-02-12
# ...        ...     ...          ...     ...          ...         ...
# 331598  499873    d002      Finance   40000        s0001  1960-12-10
# 331599  499950    d002      Finance   54788        s0001  1964-07-15
# 331600  499977    d002      Finance   70216        s0001  1956-06-05
# 331601  499989    d002      Finance   64183        s0002  1954-05-26
# 331602  499998    d002      Finance   40000        s0001  1956-09-05
#
#        first_name  last_name sex   hire_date
# 0          Georgi    Facello   M  1986-06-26
# 1          Anneke    Preusig   F  1989-06-02
# ...

# %%
# calculate average salaries by department 
salary_agg = final_merge.groupby("dept_name").agg({"salary":["mean"]})
salary_agg
# Out:
#                           salary
#                             mean
# dept_name
# Customer Service    47998.670441
# Development         48697.334663
# Finance             59533.516546
# Human Resources     44678.646801
# Marketing           61095.897383
# Production          48760.450827
# Quality Management  46456.005717
# Research            48850.189719
# Sales               69832.127151

# %%
# plot salary averages by department
salary_avg = final_merge.groupby("dept_name").mean()["salary"]
total_meas_df = pd.DataFrame({"Total Measures":salary_avg})

total_meas_df.plot(kind='bar')
plt.title("Average Salary by Department", fontsize=22)
plt.show()

# %%
final_merge.hist("salary",bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fad24de1748>]],
#       dtype=object)
